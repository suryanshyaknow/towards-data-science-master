# %%
import pandas as pd

# %%
### try this:

# df1 = pd.read_excel(r'D:\iNeuron\4. Pandas\data fsds\Attribute DataSet.xlsx', header=None, names = ['x', 'y', 'z'])
# df1

# %%
df1 = pd.read_excel(r'D:\iNeuron\4. Pandas\data fsds\Attribute DataSet.xlsx', header=None, names = ['x', 'y', 'z'])
df1.head()
# Out:
#                                                                                                               x  \
# Dress_ID   Style   Price   Rating Size Season NeckLine SleeveLength waiseline Material   FabricType  Decoration
# 1006032852 Sexy    Low     4.6    M    Summer o-neck   sleevless    empire    NaN        chiffon        ruffles
# 1212192089 Casual  Low     0      L    Summer o-neck   Petal        natural   microfiber NaN            ruffles
# 1190380701 vintage High    0      L    Automn o-neck   full         natural   polyster   NaN                NaN
# 966005983  Brief   Average 4.6    L    Spring o-neck   full         natural   silk       chiffon     embroidary
#
#                                                                                                                 y  \
# Dress_ID   Style   Price   Rating Size Season NeckLine SleeveLength waiseline Material   FabricType  Pattern Type
# ...

# %%
 type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
haber = pd.read_csv(r"D:\iNeuron\4. Pandas\data fsds\haberman.csv", sep=',', header=None, names=["Age of patient at time of operation","Patient's year of operation (year - 1900)", "Number of positive axillary nodes detected", "Survival status"]).head()
haber
# Out:
#    Age of patient at time of operation  \
# 0                                   30
# 1                                   30
# 2                                   30
# 3                                   31
# 4                                   31
#
#    Patient's year of operation (year - 1900)  \
# 0                                         64
# 1                                         62
# 2                                         65
# 3                                         59
# 4                                         65
#
#    Number of positive axillary nodes detected  Survival status
# 0                                           1                1
# 1                                           3                1
# 2                                           0                1
# 3                                           2                1
# 4                                           4                1

# %%
haber.to_csv("myhaber.csv")

# %% [markdown]
# https://github.com/selva86/datasets/blob/master/Prestige.csv
# <br>
# Raw: https://raw.githubusercontent.com/selva86/datasets/master/Prestige.csv

# %%
pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/Prestige.csv").head()
# Out:
#    education  income  women  prestige  census  type
# 0      13.11   12351  11.16      68.8    1113  prof
# 1      12.26   25879   4.02      69.1    1130  prof
# 2      12.77    9271  15.70      63.4    1171  prof
# 3      11.42    8865   9.11      56.8    1175  prof
# 4      14.62    8403  11.68      73.5    2111  prof

# %%
pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# ...

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues").head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
df1 = pd.read_excel(r'D:\iNeuron\4. Pandas\data fsds\Attribute DataSet.xlsx')
df1.head()

## lets convert it into json format

df1.to_json("Attributes__json.json")

# %%
df1.to_csv("Attributes.csv", index=None)
